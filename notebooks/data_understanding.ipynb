# %% [markdown]
# # Data Understanding
#
# This notebook explores the dataset to understand student performance factors.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Data
df = pd.read_csv('../dataset/raw_data/student_data.csv')
df.head()

# %%
df.info()

# %%
df.describe()
